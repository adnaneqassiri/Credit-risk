# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_dir = r"./../data/raw"

files = os.listdir(data_dir)
files = [f for f in files if f != "placeholder"]
print(files)
# Out:
# ['application_test.csv', 'application_train.csv', '.~lock.bureau.csv#', 'POS_CASH_balance.csv', 'installments_payments.csv', 'bureau.csv', 'bureau_balance.csv', 'previous_application.csv', 'HomeCredit_columns_description.csv', 'credit_card_balance.csv', 'sample_submission.csv']

# %%
file_name = 'installments_payments.csv'
Ins_Pay = pd.read_csv(os.path.join(data_dir, file_name))

# %%
Ins_Pay.isna().sum()
# Out:
# SK_ID_PREV                   0
# SK_ID_CURR                   0
# NUM_INSTALMENT_VERSION       0
# NUM_INSTALMENT_NUMBER        0
# DAYS_INSTALMENT              0
# DAYS_ENTRY_PAYMENT        2905
# AMT_INSTALMENT               0
# AMT_PAYMENT               2905
# dtype: int64

# %%
Ins_Pay.head(50)
# Out:
#     SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0      1054186      161674                     1.0                      6
# 1      1330831      151639                     0.0                     34
# 2      2085231      193053                     2.0                      1
# 3      2452527      199697                     1.0                      3
# 4      2714724      167756                     1.0                      2
# 5      1137312      164489                     1.0                     12
# 6      2234264      184693                     4.0                     11
# 7      1818599      111420                     2.0                      4
# 8      2723183      112102                     0.0                     14
# 9      1413990      109741                     1.0                      4
# 10     1782554      106597                     1.0                      3
# 11     2558880      154793                     1.0                      8
# ...

# %%
Ins_Pay[Ins_Pay['DAYS_ENTRY_PAYMENT'].isna()]
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 3764207      1531600      103793                     1.0
# 3764208      1947105      159974                     1.0
# 3764209      1843773      167270                     1.0
# 3764210      1691592      192536                     1.0
# 3764211      1531299      157088                     0.0
# ...              ...         ...                     ...
# 13605396     2186857      428057                     0.0
# 13605397     1310347      414406                     0.0
# 13605398     1308766      402199                     0.0
# 13605399     1062206      409297                     0.0
# 13605400     2448869      434321                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 3764207                       7           -668.0                 NaN
# 3764208                      24            -36.0                 NaN
# 3764209                      22            -20.0                 NaN
# ...

# %%
Ins_Pay['payment_time_delay'] = Ins_Pay['DAYS_ENTRY_PAYMENT'] - Ins_Pay['DAYS_INSTALMENT']
Ins_Pay.loc[Ins_Pay['payment_time_delay'] < 0,'payment_time_delay' ] = 0
Ins_Pay.head(10)
# Out:
#    SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0     1054186      161674                     1.0                      6
# 1     1330831      151639                     0.0                     34
# 2     2085231      193053                     2.0                      1
# 3     2452527      199697                     1.0                      3
# 4     2714724      167756                     1.0                      2
# 5     1137312      164489                     1.0                     12
# 6     2234264      184693                     4.0                     11
# 7     1818599      111420                     2.0                      4
# 8     2723183      112102                     0.0                     14
# 9     1413990      109741                     1.0                      4
#
#    DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  AMT_INSTALMENT  AMT_PAYMENT  \
# 0          -1180.0             -1187.0        6948.360     6948.360
# ...

# %%
Ins_Pay['payment_amount_diff'] = Ins_Pay['AMT_PAYMENT'] - Ins_Pay['AMT_INSTALMENT']
Ins_Pay
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 0            1054186      161674                     1.0
# 1            1330831      151639                     0.0
# 2            2085231      193053                     2.0
# 3            2452527      199697                     1.0
# 4            2714724      167756                     1.0
# ...              ...         ...                     ...
# 13605396     2186857      428057                     0.0
# 13605397     1310347      414406                     0.0
# 13605398     1308766      402199                     0.0
# 13605399     1062206      409297                     0.0
# 13605400     2448869      434321                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 0                             6          -1180.0             -1187.0
# 1                            34          -2156.0             -2156.0
# 2                             1            -63.0               -63.0
# ...

# %%
#
